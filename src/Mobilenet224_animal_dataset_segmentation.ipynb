# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita018/Image-Segmentation/blob/master/src/Mobilenet224_animal_dataset_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing the examples from TF
pip install -q git+https://github.com/tensorflow/examples.git
# Out:
#   Building wheel for tensorflow-examples (setup.py) ... done

# %%
# !pip install -q pyyaml h5py

# %%
# importing the libraries and packages
import tensorflow as tf
import numpy as np
import os
from tensorflow_examples.models.pix2pix import pix2pix

import tensorflow_datasets as tfds
tfds.disable_progress_bar()
from tensorflow import keras

from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
# downloading the dataset
dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)
# Out:
# Downloading and preparing dataset oxford_iiit_pet/3.1.0 (download: 801.24 MiB, generated: Unknown size, total: 801.24 MiB) to /root/tensorflow_datasets/oxford_iiit_pet/3.1.0...
# Shuffling and writing examples to /root/tensorflow_datasets/oxford_iiit_pet/3.1.0.incompleteCGHDGV/oxford_iiit_pet-train.tfrecord
# Shuffling and writing examples to /root/tensorflow_datasets/oxford_iiit_pet/3.1.0.incompleteCGHDGV/oxford_iiit_pet-test.tfrecord
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/3.1.0. Subsequent calls will reuse this data.

# %%
# normalize function makes the image pixel intensities range between 0 and 1 
# makes the classes of mask range from 0 to n
def normalize(input_image, input_mask):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  input_mask -= 1
  return input_image, input_mask

# %%
# this function resizes the images to 224 X 224 
# for 50% of the images it flips the images for better generalization of the model
# the input object datapoint is expected to have the image and segmentation_mask
@tf.function
def load_image_train(datapoint):
  input_image = tf.image.resize(datapoint['image'], (224, 224))
  input_mask = tf.image.resize(datapoint['segmentation_mask'], (224, 224))

  if tf.random.uniform(()) > 0.5:
    input_image = tf.image.flip_left_right(input_image)
    input_mask = tf.image.flip_left_right(input_mask)

  input_image, input_mask = normalize(input_image, input_mask)

  return input_image, input_mask

# %%
# loading the image for test dataset, which won't be part of the tf graph
# there is no flipping required for the test dataset, as we need to evaluate them as it is
def load_image_test(datapoint):
  input_image = tf.image.resize(datapoint['image'], (224,224))
  input_mask = tf.image.resize(datapoint['segmentation_mask'], (224, 224))

  input_image, input_mask = normalize(input_image, input_mask)

  return input_image, input_mask

# %%
# some statistics about the dataset
TRAIN_LENGTH = info.splits['train'].num_examples
BATCH_SIZE = 64
BUFFER_SIZE = 1000
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

print("Train length:", TRAIN_LENGTH)
# Out:
# Train length: 3680

# %%
# loading the dataset from the object
train = dataset['train'].map(load_image_train, num_parallel_calls=tf.data.experimental.AUTOTUNE)
test = dataset['test'].map(load_image_test)

# %%
# exploring the elements contained in the dataset
for i in dataset['train'].take(1):
  print(i.keys())
  filename=i['file_name']
  image=i['image']
  seg=i['segmentation_mask']
  img=image.numpy()
  plt.imshow(img)
  plt.show()
  seg=seg.numpy()
  print(np.unique(seg))
# Out:
# dict_keys(['file_name', 'image', 'label', 'segmentation_mask', 'species'])
# [1 2 3]

# %%
# shuffling the training dataset randomly and prefetching the training dataset for faster train
train_dataset = train.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
train_dataset = train_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
test_dataset = test.batch(BATCH_SIZE)

# %%
# this function displays the images 
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

# %%
def unet_model(output_channels,down_stack,up_stack):
  inputs = tf.keras.layers.Input(shape=[224, 224, 3])
  x = inputs

  # Downsampling through the model
  skips = down_stack(x)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  
  for up, skip in zip(up_stack, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()
    x = concat([x, skip])

  # This is the last layer of the model
  last = tf.keras.layers.Conv2DTranspose(
      output_channels, 3, strides=2,
      padding='same')  #64x64 -> 224x224

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
# Define the sequential model
def create_model(base_model,OUTPUT_CHANNELS):
  # building these layers on top the pretrained model

  layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
  ]
  layers = [base_model.get_layer(name).output for name in layer_names]
  down_stack = tf.keras.Model(inputs=base_model.input, outputs=layers)
  down_stack.trainable = False
  up_stack = [
    pix2pix.upsample(512, 3),  # 4x4 -> 8x8
    pix2pix.upsample(256, 3),  # 8x8 -> 16x16
    pix2pix.upsample(128, 3),  # 16x16 -> 32x32
    pix2pix.upsample(64, 3),   # 32x32 -> 64x64
  ]
  model = unet_model(OUTPUT_CHANNELS,down_stack,up_stack)

  model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

  return model

# %%
# Model specific details

OUTPUT_CHANNELS = 3
# pretrained MobileNetV2 model from keras applications
base_model = tf.keras.applications.MobileNetV2(input_shape=[224, 224, 3], include_top=False)
model = create_model(base_model,OUTPUT_CHANNELS)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# model (Model)                   [(None, 112, 112, 96 1841984     input_2[0][0]
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 14, 14, 512)  1476608     model[1][4]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 1088) 0           sequential[0][0]
#                                                                  model[1][3]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 28, 28, 256)  2507776     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 448)  0           sequential_1[0][0]
#                                                                  model[1][2]
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 56, 56, 128)  516608      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 272)  0           sequential_2[0][0]
#                                                                  model[1][1]
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 112, 112, 64) 156928      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 112, 112, 160 0           sequential_3[0][0]
#                                                                  model[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 224, 224, 3)  4323        concatenate_3[0][0]
# ==================================================================================================
# Total params: 6,504,227
# Trainable params: 4,660,323
# Non-trainable params: 1,843,904
# __________________________________________________________________________________________________

# %%
def create_mask(pred_mask):
  pred_mask = tf.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

# %%
for image, mask in train.take(1):
  sample_image, sample_mask = image, mask
  display([sample_image, sample_mask])

# %%
def show_predictions(dataset=None, num=1,model_to_use=model):
  model=model_to_use
  if dataset:
    for image, mask in dataset.take(num):
      pred_mask = model.predict(image)
      display([image[0], mask[0], create_mask(pred_mask)])
  else:
    display([sample_image, sample_mask,
             create_mask(model.predict(sample_image[tf.newaxis, ...]))])

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    clear_output(wait=True)
    show_predictions()
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))

# %%
#checkpoint_path = "/content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/training_weights_animal/cp.ckpt"
checkpoint_path = "/content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1, frequency = 5)
# Create a basic model instance
model = create_model(base_model,OUTPUT_CHANNELS)
# Save the weights using the `checkpoint_path` format
model.save_weights(checkpoint_path)

EPOCHS = 20
VAL_SUBSPLITS = 5
VALIDATION_STEPS = info.splits['test'].num_examples//BATCH_SIZE//VAL_SUBSPLITS

model_history = model.fit(train_dataset, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=test_dataset,
                          callbacks=[cp_callback])
# Out:
# Epoch 1/20
# 57/57 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.8248
# Epoch 00001: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 19s 328ms/step - loss: 0.4443 - accuracy: 0.8248 - val_loss: 0.4048 - val_accuracy: 0.8552
# Epoch 2/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.8918
# Epoch 00002: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 251ms/step - loss: 0.2666 - accuracy: 0.8918 - val_loss: 0.3009 - val_accuracy: 0.8832
# Epoch 3/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.8967
# Epoch 00003: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 250ms/step - loss: 0.2496 - accuracy: 0.8967 - val_loss: 0.2718 - val_accuracy: 0.8922
# Epoch 4/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.8996
# Epoch 00004: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 249ms/step - loss: 0.2408 - accuracy: 0.8996 - val_loss: 0.2584 - val_accuracy: 0.8947
# Epoch 5/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2327 - accuracy: 0.9022
# Epoch 00005: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 248ms/step - loss: 0.2327 - accuracy: 0.9022 - val_loss: 0.2679 - val_accuracy: 0.8903
# Epoch 6/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9035
# Epoch 00006: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 247ms/step - loss: 0.2280 - accuracy: 0.9035 - val_loss: 0.2723 - val_accuracy: 0.8903
# Epoch 7/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9071
# Epoch 00007: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 248ms/step - loss: 0.2189 - accuracy: 0.9071 - val_loss: 0.2453 - val_accuracy: 0.9006
# Epoch 8/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9081
# Epoch 00008: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 247ms/step - loss: 0.2153 - accuracy: 0.9081 - val_loss: 0.2522 - val_accuracy: 0.8991
# Epoch 9/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9092
# Epoch 00009: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 249ms/step - loss: 0.2124 - accuracy: 0.9092 - val_loss: 0.2583 - val_accuracy: 0.8977
# Epoch 10/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9111
# Epoch 00010: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 250ms/step - loss: 0.2066 - accuracy: 0.9111 - val_loss: 0.2482 - val_accuracy: 0.9005
# Epoch 11/20
# 57/57 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9126
# Epoch 00011: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 250ms/step - loss: 0.2021 - accuracy: 0.9126 - val_loss: 0.2405 - val_accuracy: 0.9031
# Epoch 12/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9161
# Epoch 00012: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 250ms/step - loss: 0.1931 - accuracy: 0.9161 - val_loss: 0.2526 - val_accuracy: 0.9015
# Epoch 13/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1914 - accuracy: 0.9166
# Epoch 00013: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 248ms/step - loss: 0.1914 - accuracy: 0.9166 - val_loss: 0.2423 - val_accuracy: 0.9035
# Epoch 14/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9174
# Epoch 00014: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 247ms/step - loss: 0.1897 - accuracy: 0.9174 - val_loss: 0.2416 - val_accuracy: 0.9039
# Epoch 15/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9198
# Epoch 00015: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 248ms/step - loss: 0.1825 - accuracy: 0.9198 - val_loss: 0.2635 - val_accuracy: 0.8974
# Epoch 16/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9221
# Epoch 00016: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 250ms/step - loss: 0.1768 - accuracy: 0.9221 - val_loss: 0.2524 - val_accuracy: 0.9009
# Epoch 17/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9230
# Epoch 00017: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 248ms/step - loss: 0.1741 - accuracy: 0.9230 - val_loss: 0.2497 - val_accuracy: 0.9017
# Epoch 18/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9250
# Epoch 00018: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 248ms/step - loss: 0.1689 - accuracy: 0.9250 - val_loss: 0.2617 - val_accuracy: 0.9008
# Epoch 19/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9276
# Epoch 00019: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 249ms/step - loss: 0.1623 - accuracy: 0.9276 - val_loss: 0.2648 - val_accuracy: 0.8995
# Epoch 20/20
# 57/57 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9283
# Epoch 00020: saving model to /content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt
# 57/57 [==============================] - 14s 246ms/step - loss: 0.1601 - accuracy: 0.9283 - val_loss: 0.2628 - val_accuracy: 0.9034

# %%
# mouting google drive
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-04cda7da6ae1> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive',force_remount=True)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     152       raise ValueError('Mountpoint must not be a symlink')
#     153     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 154       raise ValueError('Mountpoint must not already contain files')
#     155     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#     156       raise ValueError('Mountpoint must either be a directory or not exist')
#
# ValueError: Mountpoint must not already contain files

# %%
checkpoint_path = "/content/gdrive/My Drive/UBDS_college_work/SelfDrivingProject/Code/Semantic-Segmentation-Suite/animal_dataset/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
latest = tf.train.latest_checkpoint(checkpoint_dir)
print(latest)

# %%
show_predictions(test_dataset, 3,model)

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(EPOCHS)

plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
# Create a new model instance
model2 = create_model(base_model,OUTPUT_CHANNELS)

# Load the previously saved weights
latest = tf.train.latest_checkpoint(checkpoint_dir)
print(latest)
model2.load_weights(latest)
show_predictions(test_dataset, 3,model2)

# %%
loss = model2.history['loss']
val_loss = model2.history['val_loss']

epochs = range(EPOCHS)

plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
# Upload and Test your own image to see if it's classified as a Road or not

import numpy as np
import cv2
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  test_img=cv2.imread(path,1)
  test_img =cv2.cvtColor(test_img,cv2.COLOR_BGR2RGB)
  test_img =cv2.resize(test_img,(224,224))
  test_img = tf.cast(test_img, tf.float32) / 255.0
  
  
  # x = image.img_to_array(img)
  x = np.expand_dims(test_img, axis=0)
  pred=model.predict(x)
  pred_0=pred[0]
  # pred_0=pred[0]
  pred_max=np.zeros((pred_0.shape[0],pred_0.shape[1]))
  for i in range(pred_0.shape[0]):
    for j in range(pred_0.shape[1]):
      if pred_0[i,j,0]>pred_0[i,j,1] and pred_0[i,j,0]>pred_0[i,j,2]:
        pred_max[i,j]=0
      elif pred_0[i,j,1]>pred_0[i,j,0] and pred_0[i,j,1]>pred_0[i,j,2]:
        pred_max[i,j]=1
      else:
        pred_max[i,j]=2
  plt.imshow(pred_max)
  plt.show()
# Out:
#      <input type="file" id="files-dabcda45-5f91-4b4f-b90a-421cba0c4fb4" name="files[]" multiple disabled />
#      <output id="result-dabcda45-5f91-4b4f-b90a-421cba0c4fb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.JPG to dog (1).JPG
